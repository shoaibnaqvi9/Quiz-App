# %% [markdown]
# # Quiz App Using Python Data Structures

# %%
print("------------Python Data Structures Quiz Application------------")
score = 0
quiz_questions = {
    'Which of the following is the correct syntax to output "Hello World" in Python?' : ['echo "Hello World"' , 'print("Hello World")' , 'printf("Hello World")', 'cout << "Hello World"'],
    'Which of the following data types is immutable in Python?' : ['List' , 'Dictionary' , 'Set', 'Tuple'],
    'Which of the following is not a valid Python data type?' : ['int' , 'float' , 'str', 'real'],
    'How do you start a comment in Python?' : ['//' , '/*' , '#', '<!--'],
    'Which of the following statements is used to create a function in Python?' : ['function myFunc():' , 'def myFunc():' , 'create myFunc():', 'define myFunc():'],
    'What data type is used to represent textual data in Python?' : ['Integer' , 'Float' , 'String', 'Boolean'],
    'Which function is used to get the length of a list in Python?' : ['size()' , 'length()' , 'count()', 'len()'],
    'Which of the following is a valid variable name in Python?' : ['1variable' , 'variable_name' , 'variable-name', 'variable name'],
    'What is the keyword used to define a conditional statement in Python?' : ['if' , 'when' , 'condition', 'switch'],
    'What keyword is used to start a loop that iterates over a sequence of elements?' : ['loop' , 'repeat' , 'for', 'iterate']
}
correct_options = ('B','D','D','C','B','C','D','B','A','C')

for index, (question, option) in enumerate(quiz_questions.items()):
    print(f"{index+1}- {question}")
    print("A. ",option[0], "\nB. ", option[1], "\nC. ", option[2], "\nD. ", option[3])
    
    user_defined = input("Choose any option? ")
    answer = user_defined.upper()
    if answer == correct_options[index]:
        print("Correct!")
        print()
        score += 1
    else:
        print(f"The correct answer is {correct_options[index]} not {answer}")
        print()

score_percent = (score / len(quiz_questions)) * 100
print(f"Your total score is {score}")
print(f"Your secured {score_percent}%")
# Out:
# ------------Python Data Structures Quiz Application------------
# 1- Which of the following is the correct syntax to output "Hello World" in Python?
# A.  echo "Hello World"
# B.  print("Hello World")
# C.  printf("Hello World")
# D.  cout << "Hello World"
# Choose any option? a
# The correct answer is B not A
#
# 2- Which of the following data types is immutable in Python?
# A.  List
# B.  Dictionary
# C.  Set
# D.  Tuple
# Choose any option? a
# The correct answer is D not A
#
# 3- Which of the following is not a valid Python data type?
# A.  int
# B.  float
# C.  str
# D.  real
# Choose any option? a
# The correct answer is D not A
#
# 4- How do you start a comment in Python?
# A.  //
# B.  /*
# C.  #
# D.  <!--
# Choose any option? a
# The correct answer is C not A
#
# 5- Which of the following statements is used to create a function in Python?
# A.  function myFunc():
# B.  def myFunc():
# C.  create myFunc():
# D.  define myFunc():
# Choose any option? a
# The correct answer is B not A
#
# 6- What data type is used to represent textual data in Python?
# A.  Integer
# B.  Float
# C.  String
# D.  Boolean
# Choose any option? a
# The correct answer is C not A
#
# 7- Which function is used to get the length of a list in Python?
# A.  size()
# B.  length()
# C.  count()
# D.  len()
# Choose any option? a
# The correct answer is D not A
#
# 8- Which of the following is a valid variable name in Python?
# A.  1variable
# B.  variable_name
# C.  variable-name
# D.  variable name
# Choose any option? a
# The correct answer is B not A
#
# 9- What is the keyword used to define a conditional statement in Python?
# A.  if
# B.  when
# C.  condition
# D.  switch
# Choose any option? a
# Correct!
#
# 10- What keyword is used to start a loop that iterates over a sequence of elements?
# A.  loop
# B.  repeat
# C.  for
# D.  iterate
# Choose any option? a
# The correct answer is C not A
#
# Your total score is 1
# Your secured 10.0%
